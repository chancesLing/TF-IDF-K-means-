# %%
import ssl
import bs4
import re
import requests
import csv
import codecs
import time

from urllib import request, error

context = ssl._create_unverified_context()


class DouBanSpider:
    def __init__(self):
        self.userAgent = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36"
        self.headers = {"User-Agent": self.userAgent}

    # 拿到豆瓣图书的分类标签
    def getBookCategroies(self):
        try:
            url = "https://book.douban.com/tag/?view=type&icn=index-sorttags-all"
            response = request.urlopen(url, context=context)
            content = response.read().decode("utf-8")
            return content
        except error.HTTPError as identifier:
            print("errorCode: " + identifier.code + "errrorReason: " + identifier.reason)
            return None

    # 找到每个标签的内容
    def getCategroiesContent(self):
        content = self.getBookCategroies()
        if not content:
            print("页面抓取失败...")
            return None
        soup = bs4.BeautifulSoup(content, "lxml")
        categroyMatch = re.compile(r"^/tag/*")
        categroies = []
        for categroy in soup.find_all("a", {"href": categroyMatch}):
            if categroy:
                categroies.append(categroy.string)
        return categroies

    # 拿到每个标签的链接
    def getCategroyLink(self):
        categroies = self.getCategroiesContent()
        categroyLinks = []
        for item in categroies:
            link = "https://book.douban.com/tag/" + str(item)
            categroyLinks.append(link)
        return categroyLinks

    def getBookInfo(self, categroyLinks):
        self.setCsvTitle()
        categroies = categroyLinks
        try:
            for link in categroies:
                print("正在爬取：" + link)
                bookList = []
                response = requests.get(link)
                soup = bs4.BeautifulSoup(response.text, 'lxml')
                bookCategroy = soup.h1.string
                for book in soup.find_all("li", {"class": "subject-item"}):
                    bookSoup = bs4.BeautifulSoup(str(book), "lxml")
                    bookTitle = bookSoup.h2.a["title"]
                    bookAuthor = bookSoup.find("div", {"class": "pub"})
                    bookComment = bookSoup.find("span", {"class": "pl"})
                    bookContent = bookSoup.li.p
                    # print(bookContent)
                    if bookTitle and bookAuthor and bookComment and bookContent:
                        bookList.append([bookTitle.strip(),bookCategroy.strip() , bookAuthor.string.strip(),
                                         bookComment.string.strip(), bookContent.string.strip()])
                self.saveBookInfo(bookList)
                time.sleep(3)

            print("爬取结束....")

        except error.HTTPError as identifier:
            print("errorCode: " + identifier.code + "errrorReason: " + identifier.reason)
            return None

    def setCsvTitle(self):
        csvFile = codecs.open("data/data.csv", 'a', 'utf_8_sig')
        try:
            writer = csv.writer(csvFile)
            writer.writerow(['title', 'tag', 'info', 'comments', 'content'])
        finally:
            csvFile.close()

    def saveBookInfo(self, bookList):
        bookList = bookList
        csvFile = codecs.open("data/data.csv", 'a', 'utf_8_sig')
        try:
            writer = csv.writer(csvFile)
            for book in bookList:
                writer.writerow(book)
        finally:
            csvFile.close()

    def start(self):
        categroyLink = self.getCategroyLink()
        self.getBookInfo(categroyLink)


douBanSpider = DouBanSpider()
douBanSpider.start()
# Out:
# 正在爬取：https://book.douban.com/tag/小说
# 正在爬取：https://book.douban.com/tag/外国文学
# 正在爬取：https://book.douban.com/tag/文学
# 正在爬取：https://book.douban.com/tag/随笔
# 正在爬取：https://book.douban.com/tag/中国文学
# 正在爬取：https://book.douban.com/tag/经典
# 正在爬取：https://book.douban.com/tag/日本文学
# 正在爬取：https://book.douban.com/tag/散文
# 正在爬取：https://book.douban.com/tag/村上春树
# 正在爬取：https://book.douban.com/tag/诗歌
# 正在爬取：https://book.douban.com/tag/童话
# 正在爬取：https://book.douban.com/tag/儿童文学
# 正在爬取：https://book.douban.com/tag/古典文学
# 正在爬取：https://book.douban.com/tag/名著
# 正在爬取：https://book.douban.com/tag/王小波
# 正在爬取：https://book.douban.com/tag/余华
# 正在爬取：https://book.douban.com/tag/杂文
# 正在爬取：https://book.douban.com/tag/张爱玲
# 正在爬取：https://book.douban.com/tag/当代文学
# 正在爬取：https://book.douban.com/tag/钱钟书
# 正在爬取：https://book.douban.com/tag/外国名著
# 正在爬取：https://book.douban.com/tag/鲁迅
# 正在爬取：https://book.douban.com/tag/诗词
# 正在爬取：https://book.douban.com/tag/茨威格
# 正在爬取：https://book.douban.com/tag/米兰·昆德拉
# 正在爬取：https://book.douban.com/tag/杜拉斯
# 正在爬取：https://book.douban.com/tag/港台
# 正在爬取：https://book.douban.com/tag/漫画
# 正在爬取：https://book.douban.com/tag/推理
# 正在爬取：https://book.douban.com/tag/绘本
# 正在爬取：https://book.douban.com/tag/青春
# 正在爬取：https://book.douban.com/tag/东野圭吾
# 正在爬取：https://book.douban.com/tag/科幻
# 正在爬取：https://book.douban.com/tag/悬疑
# 正在爬取：https://book.douban.com/tag/言情
# 正在爬取：https://book.douban.com/tag/奇幻
# 正在爬取：https://book.douban.com/tag/武侠
# 正在爬取：https://book.douban.com/tag/日本漫画
# 正在爬取：https://book.douban.com/tag/推理小说
# 正在爬取：https://book.douban.com/tag/耽美
# 正在爬取：https://book.douban.com/tag/韩寒
# 正在爬取：https://book.douban.com/tag/亦舒
# 正在爬取：https://book.douban.com/tag/网络小说
# 正在爬取：https://book.douban.com/tag/三毛
# 正在爬取：https://book.douban.com/tag/科幻小说
# 正在爬取：https://book.douban.com/tag/安妮宝贝
# 正在爬取：https://book.douban.com/tag/阿加莎·克里斯蒂
# 正在爬取：https://book.douban.com/tag/金庸
# 正在爬取：https://book.douban.com/tag/穿越
# 正在爬取：https://book.douban.com/tag/郭敬明
# 正在爬取：https://book.douban.com/tag/轻小说
# 正在爬取：https://book.douban.com/tag/魔幻
# 正在爬取：https://book.douban.com/tag/青春文学
# 正在爬取：https://book.douban.com/tag/几米
# 正在爬取：https://book.douban.com/tag/幾米
# 正在爬取：https://book.douban.com/tag/张小娴
# 正在爬取：https://book.douban.com/tag/J.K.罗琳
# 正在爬取：https://book.douban.com/tag/古龙
# 正在爬取：https://book.douban.com/tag/高木直子
# 正在爬取：https://book.douban.com/tag/沧月
# 正在爬取：https://book.douban.com/tag/校园
# 正在爬取：https://book.douban.com/tag/落落
# 正在爬取：https://book.douban.com/tag/张悦然
# 正在爬取：https://book.douban.com/tag/历史
# 正在爬取：https://book.douban.com/tag/心理学
# 正在爬取：https://book.douban.com/tag/哲学
# 正在爬取：https://book.douban.com/tag/传记
# 正在爬取：https://book.douban.com/tag/社会学
# 正在爬取：https://book.douban.com/tag/文化
# 正在爬取：https://book.douban.com/tag/艺术
# 正在爬取：https://book.douban.com/tag/社会
# 正在爬取：https://book.douban.com/tag/设计
# 正在爬取：https://book.douban.com/tag/政治
# 正在爬取：https://book.douban.com/tag/建筑
# 正在爬取：https://book.douban.com/tag/宗教
# 正在爬取：https://book.douban.com/tag/电影
# 正在爬取：https://book.douban.com/tag/政治学
# 正在爬取：https://book.douban.com/tag/数学
# 正在爬取：https://book.douban.com/tag/中国历史
# 正在爬取：https://book.douban.com/tag/回忆录
# 正在爬取：https://book.douban.com/tag/思想
# 正在爬取：https://book.douban.com/tag/国学
# 正在爬取：https://book.douban.com/tag/人物传记
# 正在爬取：https://book.douban.com/tag/人文
# 正在爬取：https://book.douban.com/tag/艺术史
# 正在爬取：https://book.douban.com/tag/音乐
# 正在爬取：https://book.douban.com/tag/绘画
# 正在爬取：https://book.douban.com/tag/戏剧
# 正在爬取：https://book.douban.com/tag/西方哲学
# 正在爬取：https://book.douban.com/tag/二战
# 正在爬取：https://book.douban.com/tag/近代史
# 正在爬取：https://book.douban.com/tag/军事
# 正在爬取：https://book.douban.com/tag/佛教
# 正在爬取：https://book.douban.com/tag/考古
# 正在爬取：https://book.douban.com/tag/自由主义
# 正在爬取：https://book.douban.com/tag/美术
# 正在爬取：https://book.douban.com/tag/爱情
# 正在爬取：https://book.douban.com/tag/成长
# 正在爬取：https://book.douban.com/tag/旅行
# 正在爬取：https://book.douban.com/tag/生活
# 正在爬取：https://book.douban.com/tag/心理
# 正在爬取：https://book.douban.com/tag/励志
# 正在爬取：https://book.douban.com/tag/女性
# 正在爬取：https://book.douban.com/tag/摄影
# 正在爬取：https://book.douban.com/tag/教育
# 正在爬取：https://book.douban.com/tag/职场
# 正在爬取：https://book.douban.com/tag/美食
# 正在爬取：https://book.douban.com/tag/游记
# 正在爬取：https://book.douban.com/tag/灵修
# 正在爬取：https://book.douban.com/tag/健康
# 正在爬取：https://book.douban.com/tag/情感
# 正在爬取：https://book.douban.com/tag/人际关系
# 正在爬取：https://book.douban.com/tag/两性
# 正在爬取：https://book.douban.com/tag/手工
# 正在爬取：https://book.douban.com/tag/养生
# 正在爬取：https://book.douban.com/tag/家居
# 正在爬取：https://book.douban.com/tag/自助游
# 正在爬取：https://book.douban.com/tag/经济学
# 正在爬取：https://book.douban.com/tag/管理
# 正在爬取：https://book.douban.com/tag/经济
# 正在爬取：https://book.douban.com/tag/商业
# 正在爬取：https://book.douban.com/tag/金融
# 正在爬取：https://book.douban.com/tag/投资
# 正在爬取：https://book.douban.com/tag/营销
# 正在爬取：https://book.douban.com/tag/理财
# 正在爬取：https://book.douban.com/tag/创业
# 正在爬取：https://book.douban.com/tag/广告
# 正在爬取：https://book.douban.com/tag/股票
# 正在爬取：https://book.douban.com/tag/企业史
# 正在爬取：https://book.douban.com/tag/策划
# 正在爬取：https://book.douban.com/tag/科普
# 正在爬取：https://book.douban.com/tag/互联网
# 正在爬取：https://book.douban.com/tag/编程
# 正在爬取：https://book.douban.com/tag/科学
# 正在爬取：https://book.douban.com/tag/交互设计
# 正在爬取：https://book.douban.com/tag/用户体验
# 正在爬取：https://book.douban.com/tag/算法
# 正在爬取：https://book.douban.com/tag/科技
# 正在爬取：https://book.douban.com/tag/web
# 正在爬取：https://book.douban.com/tag/交互
# 正在爬取：https://book.douban.com/tag/UE
# 正在爬取：https://book.douban.com/tag/通信
# 正在爬取：https://book.douban.com/tag/UCD
# 正在爬取：https://book.douban.com/tag/神经网络
# 正在爬取：https://book.douban.com/tag/程序
# 爬取结束....
